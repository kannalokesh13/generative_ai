# %%
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# Out:
# ...
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# ...
# Using cached huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# ...
#      ---------------------------------------- 0.0/129.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/129.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/129.4 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/129.4 kB 262.6 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/129.4 kB 279.3 kB/s eta 0:00:01
#      ----------------------- ------------- 81.9/129.4 kB 416.7 kB/s eta 0:00:01
#      ------------------------------- ---- 112.6/129.4 kB 467.6 kB/s eta 0:00:01
# ...

# %%
from langchain import PromptTemplate, HuggingFaceHub, LLMChain

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN']="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"

# %%
hugging_face_api_key = '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'

# %% [markdown]
# ### Text2Text Generation Models | Seq2Seq Models | Encoder-Decoder Models

# %%
prompt = PromptTemplate(
    input_variables = ['content'],
    template = "generate some names to start a start up for {content}"
)

# %% [markdown]
# #### llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0}

# %%
model1 = 'facebook/mbart-large-50'

# %%
HuggingFaceHub(repo_id='facebook/mbart-large-50', model_kwargs={'temperature':1.5})
# Out:
# HuggingFaceHub(client=<InferenceClient(model='facebook/mbart-large-50', timeout=None)>, repo_id='facebook/mbart-large-50', task='text2text-generation', model_kwargs={'temperature': 1.5})

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0}),prompt = prompt)

# %%
chain.run('laundry business')
# Out:
# C:\Users\k.vidya\Anaconda3\envs\testopenai\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# 'a laundry business'

# %%
prompt2 = PromptTemplate(
    input_variables = ['product'],
    template = "provide the good name for the company which makes the {product}"
)

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='facebook/mbart-large-50', model_kwargs={'temperature':0}),prompt = prompt2)

# %%
chain.run('clothes')
# Out:
# 'provide the good name for the company which makes the clothes'

# %%
model2 = 'facebook/mbart-large-50-one-to-many-mmt'

# %%
chain2 = LLMChain(llm=HuggingFaceHub(repo_id='facebook/mbart-large-50-one-to-many-mmt',model_kwargs={'temparature':0}),prompt=prompt2)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\Anaconda3\envs\testopenai\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# ...

# %%
model3 = 'google/flan-t5-xxl'

# %%
chain2 = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-xxl',model_kwargs={'temparature':0}),prompt=prompt2)

# %%
chain2.run('machines')
# Out:
# 'The name of the company is engraved on the machine.'

# %%
chain2.run('colorful clothes')
# Out:
# 'The company name should be written in the name of the colorful clothes.'

# %%
chain2.run('laptops')
# Out:
# 'The laptops are very good and the company is very good.'

# %%
chain3 = LLMChain(llm=HuggingFaceHub(repo_id='google/roberta2roberta_L-24_discofuse',model_kwargs={'temparature':0}),prompt=prompt2)

# %%
chain3.run('clothes')
# Out:
# 'provide the good name for the company which makes the clothes'

# %%
chain3.run('machines')
# Out:
# 'provide the good name for the company which makes the machines'

# %% [markdown]
# # Text Generation Models | Decoder Only Models

# %%
from langchain.llms import HuggingFacePipeline
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, AutoModelForSeq2SeqLM

# %%
model_id='google/flan-t5-large'

# %%
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# C:\Users\k.vidya\Anaconda3\envs\testopenai\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\k.vidya\.cache\huggingface\hub\models--google--flan-t5-large. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(model_id,device_map='auto')
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 model = AutoModelForSeq2SeqLM.from_pretrained(model_id,device_map='auto')
#
# File ~\Anaconda3\envs\testopenai\lib\site-packages\transformers\models\auto\auto_factory.py:566, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564 elif type(config) in cls._model_mapping.keys():
#     565     model_class = _get_model_class(config, cls._model_mapping)
# --> 566     return model_class.from_pretrained(
#     567         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568     )
#     569 raise ValueError(
# ...

# %%
pipeline = pipeline("text2text-generation", model=model, tokenizer=tokenizer, max_length=128)

# %%
local_llm = HuggingFacePipeline(pipeline=pipeline)

# %%
prompt = PromptTemplate(
    input_variables=["name"],
    template="Can you tell me about footballer {name}"
)

# %%
chain = LLMChain(llm=local_llm,prompt = prompt)

# %%
chain.run("sunil chetri")

# %%
prompt2 = PromptTemplate(
    input_variables=["name"],
    template="Can you tell me about crickter {name}"
)

# %%
chain2 = LLMChain(llm=local_llm,prompt = prompt2)

# %%
chain2.run("virat kholi")

# %%
chain2.run('ms dhoni')
